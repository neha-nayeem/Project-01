# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
from sklearn import datasets
pd.set_option('mode.chained_assignment', None)

# %%
#read output file
data="Data Output/Toronto_Crimes_Occurred_2014_2019.csv"
data_df= pd.read_csv(data, encoding="ISO-8859-1")
#drop na values
newtable=data_df.dropna()
newtable["reportedyear"]=newtable["reportedyear"].astype(str)
# filter out 2014 B&E Data
Year1_Break= newtable.loc[(newtable["offence"] == "B&E")&(newtable["reportedyear"] == "2014.0")]
#plot graph
type1=Year1_Break["premisetype"].value_counts()
labels=newtable["premisetype"].unique()
plt.pie(type1,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("2014 Break and Enter Premistype Breakdown")
plt.axis("equal")
plt.legend(labels,loc="lower right")
plt.show()

# %%
# filter out 2015 B&E Data
Year2_Break= newtable.loc[(newtable["offence"] == "B&E")&(newtable["reportedyear"] == "2015.0")]
type2=Year2_Break["premisetype"].value_counts()
labels=newtable["premisetype"].unique()
plt.pie(type2,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("2015 Break and Enter Premistype Breakdown")
plt.axis("equal")
plt.legend(labels,loc="lower right")
plt.show()

# %%
# filter out 2016 B&E Data
Year3_Break= newtable.loc[(newtable["offence"] == "B&E")&(newtable["reportedyear"] == "2016.0")]
type3=Year3_Break["premisetype"].value_counts()
labels=newtable["premisetype"].unique()
plt.pie(type2,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("2016 Break and Enter Premistype Breakdown")
plt.axis("equal")
plt.legend(labels,loc="lower right")

# %%
# filter out 2017 B&E Data
Year4_Break= newtable.loc[(newtable["offence"] == "B&E")&(newtable["reportedyear"] == "2017.0")]
type4=Year4_Break["premisetype"].value_counts()
labels=newtable["premisetype"].unique()
plt.pie(type2,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("2017 Break and Enter Premistype Breakdown")
plt.axis("equal")
plt.legend(labels,loc="lower right")
plt.show()

# %%
# filter out 2018 B&E Data
Year5_Break= newtable.loc[(newtable["offence"] == "B&E")&(newtable["reportedyear"] == "2018.0")]
type5=Year5_Break["premisetype"].value_counts()
labels=newtable["premisetype"].unique()
plt.pie(type2,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("2018 Break and Enter Premistype Breakdown")
plt.axis("equal")
plt.legend(labels,loc="lower right")
plt.show()

# %%
# filter out 2018 B&E Data
Year6_Break= newtable.loc[(newtable["offence"] == "B&E")&(newtable["reportedyear"] == "2019.0")]
type6=Year6_Break["premisetype"].value_counts()
labels=newtable["premisetype"].unique()
plt.pie(type2,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title("2019 Break and Enter Premistype Breakdown")
plt.axis("equal")
plt.legend(labels,loc="lower right")
plt.show()

# %%
# filter out B&E Data
B_table= newtable.loc[(newtable["offence"] == "B&E"),:]
x=B_table["premisetype"].unique()
# plot data
fig, ax = plt.subplots(figsize=(15,7))
B_table.groupby("reportedyear")["premisetype"].value_counts().unstack().plot(ax=ax)
