# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file1="Data Output/Toronto_Crimes_Occurred_2014_2019.csv"
file2="Data Output/Toronto_Crimes_2014.csv"
file3="Data Output/Toronto_Crimes_2015.csv"
file4="Data Output/Toronto_Crimes_2016.csv"
file5="Data Output/Toronto_Crimes_2017.csv"
file6="Data Output/Toronto_Crimes_2018.csv"
file7="Data Output/Toronto_Crimes_2019.csv"
crime_2014_2019=pd.read_csv(file1)
crime_2014=pd.read_csv(file2)
crime_2015=pd.read_csv(file3)
crime_2016=pd.read_csv(file4)
crime_2017=pd.read_csv(file5)
crime_2018=pd.read_csv(file6)
crime_2019=pd.read_csv(file7)
# Out:
# C:\Users\Feng\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (7,10,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
crime_2014_2019.head(1)
# Out:
#    Unnamed: 0 event_unique_id premisetype  ucr_code  ucr_ext  offence  \
# 0           0  GO-20141756319  Commercial    1430.0    100.0  Assault
#
#    reportedyear reportedmonth  reportedday  reporteddayofyear  ...  \
# 0        2014.0         March         24.0               83.0  ...
#
#   occurrenceday  occurrencedayofyear  occurrencedayofweek occurrencehour  \
# 0          24.0                 83.0           Monday                1.0
#
#        MCI  Division Hood_ID  Neighbourhood       Long        Lat
# 0  Assault       D42     132  Malvern (132) -79.199081  43.800281
#
# [1 rows x 24 columns]

# %%
# Define a function to get the number of cases based on MCI, and create a bar chart for the data
def get_number(df,year):
    mci=df[~df.duplicated(subset=["MCI"])]
    mci_list=sorted(mci["MCI"])
    num_crime=[]
    grouped_mci=df.groupby(["MCI"])["event_unique_id"].count()
    for crime in mci_list:
        print(f"In {year}, there are {grouped_mci[crime]} {crime} occurred.")
        num_crime.append(grouped_mci[crime])
    x=mci_list
    y=num_crime
    plt.bar(x,y,color="blue",alpha=0.75,align="center")
    plt.xticks(rotation=45)
    plt.xlabel("MCI")
    plt.ylabel("Number of crimes")
    plt.xlim(-1,len(num_crime))
    plt.ylim(0,max(num_crime)+1000)
    plt.legend(["Case Number"],loc="upper right")
    plt.title(f"Toronto crimes occurred {year}")
    plt.savefig(f"Image Output/Toronto Crime Numbers {year}.png")
    plt.show()

# %%
# Run the function to get total case numbers from 2014 to 2019.
get_number(crime_2014_2019,"2014-2019")
# Out:
# In 2014-2019, there are 110609 Assault occurred.
# In 2014-2019, there are 23330 Auto Theft occurred.
# In 2014-2019, there are 43214 Break and Enter occurred.
# In 2014-2019, there are 21500 Robbery occurred.
# In 2014-2019, there are 6668 Theft Over occurred.
# In 2014-2019, there are 21584 bicycle theft occurred.
# In 2014-2019, there are 431 homicide occurred.

# %%
# Run the function to get case numbers of 2014
get_number(crime_2014,2014)
# Out:
# In 2014, there are 16395 Assault occurred.
# In 2014, there are 3485 Auto Theft occurred.
# In 2014, there are 7178 Break and Enter occurred.
# In 2014, there are 3586 Robbery occurred.
# In 2014, there are 994 Theft Over occurred.
# In 2014, there are 3014 bicycle theft occurred.
# In 2014, there are 58 homicide occurred.

# %%
# Run the function to get case numbers of 2015
get_number(crime_2015,2015)
# Out:
# In 2015, there are 17738 Assault occurred.
# In 2015, there are 3195 Auto Theft occurred.
# In 2015, there are 6899 Break and Enter occurred.
# In 2015, there are 3464 Robbery occurred.
# In 2015, there are 1020 Theft Over occurred.
# In 2015, there are 3285 bicycle theft occurred.
# In 2015, there are 59 homicide occurred.

# %%
# Run the function to get case numbers of 2016
get_number(crime_2016,2016)
# Out:
# In 2016, there are 18538 Assault occurred.
# In 2016, there are 3258 Auto Theft occurred.
# In 2016, there are 6387 Break and Enter occurred.
# In 2016, there are 3613 Robbery occurred.
# In 2016, there are 1013 Theft Over occurred.
# In 2016, there are 3800 bicycle theft occurred.
# In 2016, there are 75 homicide occurred.

# %%
# Run the function to get case numbers of 2017
get_number(crime_2017,2017)
# Out:
# In 2017, there are 19086 Assault occurred.
# In 2017, there are 3545 Auto Theft occurred.
# In 2017, there are 6877 Break and Enter occurred.
# In 2017, there are 3898 Robbery occurred.
# In 2017, there are 1155 Theft Over occurred.
# In 2017, there are 3863 bicycle theft occurred.
# In 2017, there are 65 homicide occurred.

# %%
# Run the function to get case numbers of 2018
get_number(crime_2018,2018)
# Out:
# In 2018, there are 19252 Assault occurred.
# In 2018, there are 4710 Auto Theft occurred.
# In 2018, there are 7595 Break and Enter occurred.
# In 2018, there are 3531 Robbery occurred.
# In 2018, there are 1235 Theft Over occurred.
# In 2018, there are 3949 bicycle theft occurred.
# In 2018, there are 96 homicide occurred.

# %%
# Run the function to get case numbers of 2019
get_number(crime_2019,2019)
# Out:
# In 2019, there are 19600 Assault occurred.
# In 2019, there are 5137 Auto Theft occurred.
# In 2019, there are 8278 Break and Enter occurred.
# In 2019, there are 3408 Robbery occurred.
# In 2019, there are 1251 Theft Over occurred.
# In 2019, there are 3673 bicycle theft occurred.
# In 2019, there are 78 homicide occurred.

# %%
# Observation: From 2014 to 2019, Assult and Break and Enter are the top 2 most common crimes in Toronto. Homicide and Theft
# Over are the top 2 least common crimes in Toronto.

# %%
# Get the total number of crimes occurred on each year and create bar chart.
total_num=[]
total_num.append(len(crime_2014["MCI"]))
total_num.append(len(crime_2015["MCI"]))
total_num.append(len(crime_2016["MCI"]))
total_num.append(len(crime_2017["MCI"]))
total_num.append(len(crime_2018["MCI"]))
total_num.append(len(crime_2019["MCI"]))
for i in range(0,6):
    print(f"In {i+2014}, there are {total_num[i]} criminal crime occurred in Toronto.")
x_axis=["2014","2015","2016","2017","2018","2019"]
y_axis=total_num
plt.bar(x_axis,y_axis,color="red",alpha=0.5,align="center")
plt.xlabel("Year")
plt.ylabel("Total Number of Cases")
plt.xlim(-1,len(x_axis))
plt.ylim(min(y_axis)-20000,max(y_axis)+5000)
plt.legend(["Case Number"],loc="upper right")
plt.title(f"Toronto crimes vs Years")
plt.savefig(f"Image Output/Toronto crimes vs Years Bar Chart.png")
plt.show()
# Out:
# In 2014, there are 34710 criminal crime occurred in Toronto.
# In 2015, there are 35660 criminal crime occurred in Toronto.
# In 2016, there are 36684 criminal crime occurred in Toronto.
# In 2017, there are 38489 criminal crime occurred in Toronto.
# In 2018, there are 40368 criminal crime occurred in Toronto.
# In 2019, there are 41425 criminal crime occurred in Toronto.

# %%
# Create the line chart for the data above
x_axis=["2014","2015","2016","2017","2018","2019"]
y_axis=total_num
plt.plot(x_axis,y_axis,color="red")
plt.xlabel("Year")
plt.ylabel("Total Number of Cases")
plt.xlim(-1,len(x_axis))
plt.ylim(min(y_axis)-10000,max(y_axis)+5000)
plt.legend(["Case Number"],loc="upper right")
plt.title(f"Toronto crimes vs Years")
plt.savefig(f"Image Output/Toronto crimes vs Years Line Chart.png")
plt.show()

# %%
# Observation: The crime occurrence in Toronto is increasing from 2014 to 2019.

# %%
# Optional research: Get the data of different species of crime in different years.
# Define a function that can get the number of cases of each MCI type, and use line chart to show number changes throughout the year.
def mci_through_years(df,mci_type):
    mci_df=df.loc[df["MCI"]==mci_type,:]
    years=[2014,2015,2016,2017,2018,2019]
    case_num=[]
    for year in years:
        mci_by_year=mci_df.loc[mci_df["occurrenceyear"]==year,:]
        case_num.append(len(mci_by_year["MCI"]))
        print(f"There are {len(mci_by_year['MCI'])} {mci_type} occurred in Toronto in {year}.")
    x_axis=["2014","2015","2016","2017","2018","2019"]
    y_axis=case_num
    plt.plot(x_axis,y_axis,color="red")
    plt.xlabel("Year")
    plt.ylabel("Number of Cases")
    plt.xlim(-0.5,len(x_axis))
    plt.ylim(min(y_axis)*0.5,max(y_axis)+min(y_axis)*0.5)
    plt.legend(["Case Number"],loc="upper right")
    plt.title(f"{mci_type} Occurrence in Toronto from 2014 to 2019")
    plt.savefig(f"Image Output/{mci_type} Occurrence in Toronto 2014-2019.png")
    plt.show()

# %%
# Assault in Toronto
mci_through_years(crime_2014_2019,"Assault")
# Out:
# There are 16395 Assault occurred in Toronto in 2014.
# There are 17738 Assault occurred in Toronto in 2015.
# There are 18538 Assault occurred in Toronto in 2016.
# There are 19086 Assault occurred in Toronto in 2017.
# There are 19252 Assault occurred in Toronto in 2018.
# There are 19600 Assault occurred in Toronto in 2019.

# %%
# Observation: The assault cases keep increasing in Toronto from 2014 to 2019.

# %%
# Auto Theft in Toronto
mci_through_years(crime_2014_2019,"Auto Theft")
# Out:
# There are 3485 Auto Theft occurred in Toronto in 2014.
# There are 3195 Auto Theft occurred in Toronto in 2015.
# There are 3258 Auto Theft occurred in Toronto in 2016.
# There are 3545 Auto Theft occurred in Toronto in 2017.
# There are 4710 Auto Theft occurred in Toronto in 2018.
# There are 5137 Auto Theft occurred in Toronto in 2019.

# %%
# Observation: The auto theft in Toront went down from 2015 to 2016 comparing to 2014, but the number headed up since 2017.

# %%
# Bicycle Theft in Toronto
mci_through_years(crime_2014_2019,"bicycle theft")
# Out:
# There are 3014 bicycle theft occurred in Toronto in 2014.
# There are 3285 bicycle theft occurred in Toronto in 2015.
# There are 3800 bicycle theft occurred in Toronto in 2016.
# There are 3863 bicycle theft occurred in Toronto in 2017.
# There are 3949 bicycle theft occurred in Toronto in 2018.
# There are 3673 bicycle theft occurred in Toronto in 2019.

# %%
# Observation: The bycicle theft in Toronto has gone down in 2019 since 2016.

# %%
# Break and Enter in Toronto
mci_through_years(crime_2014_2019,"Break and Enter")
# Out:
# There are 7178 Break and Enter occurred in Toronto in 2014.
# There are 6899 Break and Enter occurred in Toronto in 2015.
# There are 6387 Break and Enter occurred in Toronto in 2016.
# There are 6877 Break and Enter occurred in Toronto in 2017.
# There are 7595 Break and Enter occurred in Toronto in 2018.
# There are 8278 Break and Enter occurred in Toronto in 2019.

# %%
# Observation: The lowest occurrence of Break and Enter in Toronto was in 2016.

# %%
# Homicide in Toronto
mci_through_years(crime_2014_2019,"homicide")
# Out:
# There are 58 homicide occurred in Toronto in 2014.
# There are 59 homicide occurred in Toronto in 2015.
# There are 75 homicide occurred in Toronto in 2016.
# There are 65 homicide occurred in Toronto in 2017.
# There are 96 homicide occurred in Toronto in 2018.
# There are 78 homicide occurred in Toronto in 2019.

# %%
# Obervation: The homicide occurrence in Toronto is shown in an "M" curve.

# %%
# Robbery in Toronto
mci_through_years(crime_2014_2019,"Robbery")
# Out:
# There are 3586 Robbery occurred in Toronto in 2014.
# There are 3464 Robbery occurred in Toronto in 2015.
# There are 3613 Robbery occurred in Toronto in 2016.
# There are 3898 Robbery occurred in Toronto in 2017.
# There are 3531 Robbery occurred in Toronto in 2018.
# There are 3408 Robbery occurred in Toronto in 2019.

# %%
# Observation: The robbery occurrence in Toronto keeps going down since 2017.

# %%
# Theft Over in Toronto
mci_through_years(crime_2014_2019,"Theft Over")
# Out:
# There are 994 Theft Over occurred in Toronto in 2014.
# There are 1020 Theft Over occurred in Toronto in 2015.
# There are 1013 Theft Over occurred in Toronto in 2016.
# There are 1155 Theft Over occurred in Toronto in 2017.
# There are 1235 Theft Over occurred in Toronto in 2018.
# There are 1251 Theft Over occurred in Toronto in 2019.

# %%
# Observation: The theft over occurrence in Toronto was stable before 2016, but increased by more than 10% in 2017.
